# %%
import os
print(os.getcwd())
# Out:
# d:\India Runs\TalentDNA_AI\notebooks

# %%
import sys
print(sys.path[:5])
# Out:
# ['C:\\Users\\vinit\\AppData\\Local\\Programs\\Python\\Python311\\python311.zip', 'C:\\Users\\vinit\\AppData\\Local\\Programs\\Python\\Python311\\DLLs', 'C:\\Users\\vinit\\AppData\\Local\\Programs\\Python\\Python311\\Lib', 'C:\\Users\\vinit\\AppData\\Local\\Programs\\Python\\Python311', 'd:\\India Runs\\TalentDNA_AI\\venv']

# %%
import sys
sys.path.insert(0, r"D:\India Runs\TalentDNA_AI")
from src.parser import CandidateParser
from src.career_features import CareerFeatureExtractor

# %%
parser = CandidateParser()
career_extractor = CareerFeatureExtractor()

# %%
import pandas as pd
df = pd.read_json(
    r"D:\India Runs\TalentDNA_AI\data\raw\candidates.jsonl",
    lines=True
)
df.head()
# Out:
#    candidate_id                                            profile  \
# 0  CAND_0000001  {'anonymized_name': 'Ira Vora', 'headline': 'B...
# 1  CAND_0000002  {'anonymized_name': 'Saanvi Sethi', 'headline'...
# 2  CAND_0000003  {'anonymized_name': 'Yash Agarwal', 'headline'...
# 3  CAND_0000004  {'anonymized_name': 'Anil Bose', 'headline': '...
# 4  CAND_0000005  {'anonymized_name': 'Aisha Sethi', 'headline':...
#
#                                       career_history  \
# 0  [{'company': 'Mindtree', 'title': 'Backend Eng...
# 1  [{'company': 'Wipro', 'title': 'Operations Man...
# 2  [{'company': 'TCS', 'title': 'Customer Support...
# 3  [{'company': 'Dunder Mifflin', 'title': 'Marke...
# 4  [{'company': 'Stark Industries', 'title': 'Acc...
#
#                                            education  \
# 0  [{'institution': 'Lovely Professional Universi...
# 1  [{'institution': 'Local Engineering College', ...
# 2  [{'institution': 'Local Engineering College', ...
# ...

# %%
row = df.iloc[0]
parsed = parser.parse(row)
career = career_extractor.extract(
    row["career_history"]
)
candidate = {
    **parsed,
    **career
}

'''candidate_text =
headline
+
summary
+
skills
+
experience_text
here we are getting all extended features extractions, 
This massively improves semantic retrieval.
'''
# Out:
# 'candidate_text =\nheadline\n+\nsummary\n+\nskills\n+\nexperience_text\nhere we are getting all extended features extractions, \nThis massively improves semantic retrieval.\n'

# %%
from importlib import reload
import src.parser

reload(src.parser)
# Out:
# <module 'src.parser' from 'D:\\India Runs\\TalentDNA_AI\\src\\parser.py'>

# %%
from src.parser import CandidateParser

parser = CandidateParser()

# %%
print(dir(parser))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'build_skill_text', 'extract_certification_names', 'extract_skill_names', 'parse']

# %%
row = df.iloc[0]

parsed = parser.parse(row)

print(parsed.keys())
# Out:
# dict_keys(['candidate_id', 'headline', 'summary', 'location', 'country', 'years_experience', 'current_title', 'current_company', 'company_size', 'industry', 'skill_names', 'skill_text', 'num_skills', 'certification_names', 'num_certifications', 'profile_score', 'open_to_work', 'response_rate', 'avg_response_time', 'profile_views', 'applications', 'github_score', 'search_appearance', 'saved_by_recruiters', 'interview_completion', 'offer_acceptance', 'connection_count', 'endorsements', 'notice_period_days', 'preferred_work_mode', 'willing_to_relocate', 'verified_email', 'verified_phone', 'linkedin_connected', 'candidate_text'])

# %%
career = career_extractor.extract(
    row["career_history"]
)

print(career.keys())
# Out:
# dict_keys(['current_role', 'total_duration_months', 'num_companies', 'industries', 'job_titles', 'experience_text', 'career_growth_score'])

# %%
candidate = {
    **parsed,
    **career
}

print(candidate.keys())
# Out:
# dict_keys(['candidate_id', 'headline', 'summary', 'location', 'country', 'years_experience', 'current_title', 'current_company', 'company_size', 'industry', 'skill_names', 'skill_text', 'num_skills', 'certification_names', 'num_certifications', 'profile_score', 'open_to_work', 'response_rate', 'avg_response_time', 'profile_views', 'applications', 'github_score', 'search_appearance', 'saved_by_recruiters', 'interview_completion', 'offer_acceptance', 'connection_count', 'endorsements', 'notice_period_days', 'preferred_work_mode', 'willing_to_relocate', 'verified_email', 'verified_phone', 'linkedin_connected', 'candidate_text', 'current_role', 'total_duration_months', 'num_companies', 'industries', 'job_titles', 'experience_text', 'career_growth_score'])

# %%
candidate
# Out:
# {'candidate_id': 'CAND_0000001',
#  'headline': 'Backend Engineer | SQL, Spark, Cloud',
#  'summary': "Software / data professional with 6.9 years of experience building data pipelines, backend systems, and analytics infrastructure. I'm a backend/data hybrid — Spark, Airflow, SQL warehouses are home territory; I'm building competence on the ML side. My toolkit is solid on the data engineering side — Python, SQL, Spark, Airflow, warehouse design — and I've completed a couple of self-directed ML projects (Kaggle competitions, side projects fine-tuning small models). Interested in transitioning toward more AI/ML-focused work, ideally at a company where I can leverage my existing data-infra skills while learning modern ML practice.",
#  'location': 'Toronto',
#  'country': 'Canada',
#  'years_experience': 6.9,
#  'current_title': 'Backend Engineer',
#  'current_company': 'Mindtree',
#  'company_size': '10001+',
#  'industry': 'IT Services',
#  'skill_names': ['Tailwind',
#   'NLP',
# ...

# %%
print(len(candidate))
# Out:
# 42

# %%
candidate.keys()
# Out:
# dict_keys(['candidate_id', 'headline', 'summary', 'location', 'country', 'years_experience', 'current_title', 'current_company', 'company_size', 'industry', 'skill_names', 'skill_text', 'num_skills', 'certification_names', 'num_certifications', 'profile_score', 'open_to_work', 'response_rate', 'avg_response_time', 'profile_views', 'applications', 'github_score', 'search_appearance', 'saved_by_recruiters', 'interview_completion', 'offer_acceptance', 'connection_count', 'endorsements', 'notice_period_days', 'preferred_work_mode', 'willing_to_relocate', 'verified_email', 'verified_phone', 'linkedin_connected', 'candidate_text', 'current_role', 'total_duration_months', 'num_companies', 'industries', 'job_titles', 'experience_text', 'career_growth_score'])
