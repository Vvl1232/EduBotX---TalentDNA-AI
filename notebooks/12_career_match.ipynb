# %%
import os
print(os.getcwd())

import sys
print(sys.path[:5])

import sys
sys.path.insert(0, r"D:\India Runs\TalentDNA_AI")
# Out:
# d:\India Runs\TalentDNA_AI\notebooks
# ['C:\\Users\\vinit\\AppData\\Local\\Programs\\Python\\Python311\\python311.zip', 'C:\\Users\\vinit\\AppData\\Local\\Programs\\Python\\Python311\\DLLs', 'C:\\Users\\vinit\\AppData\\Local\\Programs\\Python\\Python311\\Lib', 'C:\\Users\\vinit\\AppData\\Local\\Programs\\Python\\Python311', 'd:\\India Runs\\TalentDNA_AI\\venv']

# %%
import importlib
import src.career_match

importlib.reload(
    src.career_match
)

print(
    dir(src.career_match)
)
# Out:
# ['CareerMatchEngine', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__']

# %%
from src.career_match import (
    CareerMatchEngine
)

matcher = CareerMatchEngine()

# %%
import sys
import os

sys.path.append(
    os.path.abspath("..")
)

# %%
import src.career_match as cm

print(cm.__file__)
print(dir(cm))
# Out:
# D:\India Runs\TalentDNA_AI\src\career_match.py
# ['CareerMatchEngine', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__']

# %%
import importlib
import src.career_match as cm

importlib.reload(cm)

print(dir(cm))
# Out:
# ['CareerMatchEngine', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__']

# %%
with open(
    r"D:\India Runs\TalentDNA_AI\src\career_match.py",
    "r",
    encoding="utf-8"
) as f:

    print(f.read())
# Out:
# class CareerMatchEngine:
#
#     def __init__(self):
#
#         self.production_keywords = [
#             "spark",
#             "airflow",
#             "pipeline",
#             "feature",
#             "warehouse",
#             "etl",
#             "streaming",
#             "kafka",
#             "snowflake"
#         ]
#
#         self.ml_keywords = [
#             "machine learning",
#             "ml",
#             "model",
#             "fine-tuning",
#             "llm",
#             "embedding"
#         ]
#
#         self.search_keywords = [
#             "retrieval",
#             "ranking",
#             "recommendation",
#             "search",
#             "relevance"
#         ]
#
#         self.negative_keywords = [
#             "marketing",
#             "seo",
#             "sales",
#             "content marketing",
#             "lead generation",
#             "recruitment",
#             "hr"
#         ]
#
#     def keyword_score(
#         self,
# ...

# %%
from src.career_match import CareerMatchEngine
matcher = CareerMatchEngine()

# %%
with open("../src/career_match.py", "r") as f:
    print(f.read())
# Out:
# class CareerMatchEngine:
#
#     def __init__(self):
#
#         self.production_keywords = [
#             "spark",
#             "airflow",
#             "pipeline",
#             "feature",
#             "warehouse",
#             "etl",
#             "streaming",
#             "kafka",
#             "snowflake"
#         ]
#
#         self.ml_keywords = [
#             "machine learning",
#             "ml",
#             "model",
#             "fine-tuning",
#             "llm",
#             "embedding"
#         ]
#
#         self.search_keywords = [
#             "retrieval",
#             "ranking",
#             "recommendation",
#             "search",
#             "relevance"
#         ]
#
#         self.negative_keywords = [
#             "marketing",
#             "seo",
#             "sales",
#             "content marketing",
#             "lead generation",
#             "recruitment",
#             "hr"
#         ]
#
#     def keyword_score(
#         self,
# ...

# %%
import src.career_match as cm
matcher = cm.CareerMatchEngine()
print(type(matcher))
# Out:
# <class 'src.career_match.CareerMatchEngine'>

# %%
import src.career_match as cm
matcher = cm.CareerMatchEngine()

# %%
import pandas as pd
df = pd.read_json(
    r"D:\India Runs\TalentDNA_AI\data\raw\candidates.jsonl",
    lines=True
)

# %%
import src.career_match as cm
matcher = cm.CareerMatchEngine()

# %%
from src.parser import CandidateParser
from src.career_features import CareerFeatureExtractor
import src.career_match as cm

parser = CandidateParser()

career_extractor = CareerFeatureExtractor()

matcher = cm.CareerMatchEngine()

print("READY")
# Out:
# READY

# %%
row = df[
    df["candidate_id"] == "CAND_0000001"
].iloc[0]

parsed = parser.parse(row)

career = career_extractor.extract(
    row["career_history"]
)

candidate = {
    **parsed,
    **career
}

backend_score = matcher.score(
    candidate
)

row = df[
    df["candidate_id"] == "CAND_0000001"
].iloc[0]

print(row["career_history"])
print(row["profile"]["summary"])
print("Backend Score:", backend_score)
# Out:
# [{'company': 'Mindtree', 'title': 'Backend Engineer', 'start_date': '2024-03-08', 'end_date': None, 'duration_months': 27, 'is_current': True, 'industry': 'IT Services', 'company_size': '10001+', 'description': 'Implemented streaming data pipelines on Kafka and Spark Streaming for a real-time user-activity processing platform. Designed the schema-registry integration, the watermark/state management approach, and the deduplication logic for late-arriving events. Worked closely with the data science team to make sure feature pipelines aligned with what their models needed. Most of my career has been data engineering, with some adjacent ML exposure.'}, {'company': 'Dunder Mifflin', 'title': 'Analytics Engineer', 'start_date': '2019-07-03', 'end_date': '2024-01-08', 'duration_months': 55, 'is_current': False, 'industry': 'Paper Products', 'company_size': '201-500', 'description': 'Built and maintained data pipelines on Apache Airflow processing ~500GB of daily transactional data across 1
# ...

# %%
row = df[
    df["candidate_id"] == "CAND_0000074"
].iloc[0]

parsed = parser.parse(row)

career = career_extractor.extract(
    row["career_history"]
)

candidate = {
    **parsed,
    **career
}

ops_score = matcher.score(
    candidate
)

print("Operations Score:", ops_score)
# Out:
# Operations Score: 0

# %%
print("Backend:", backend_score)
print("Operations:", ops_score)
# Out:
# Backend: 30
# Operations: 0
