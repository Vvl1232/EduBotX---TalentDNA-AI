# %%
from src.parser import CandidateParser

# %%
parser = CandidateParser()

# %%
import pandas as pd
df = pd.read_json(
    r"D:\India Runs\TalentDNA_AI\data\raw\candidates.jsonl",
    lines=True
)
df.head()
# Out:
#    candidate_id                                            profile  \
# 0  CAND_0000001  {'anonymized_name': 'Ira Vora', 'headline': 'B...
# 1  CAND_0000002  {'anonymized_name': 'Saanvi Sethi', 'headline'...
# 2  CAND_0000003  {'anonymized_name': 'Yash Agarwal', 'headline'...
# 3  CAND_0000004  {'anonymized_name': 'Anil Bose', 'headline': '...
# 4  CAND_0000005  {'anonymized_name': 'Aisha Sethi', 'headline':...
#
#                                       career_history  \
# 0  [{'company': 'Mindtree', 'title': 'Backend Eng...
# 1  [{'company': 'Wipro', 'title': 'Operations Man...
# 2  [{'company': 'TCS', 'title': 'Customer Support...
# 3  [{'company': 'Dunder Mifflin', 'title': 'Marke...
# 4  [{'company': 'Stark Industries', 'title': 'Acc...
#
#                                            education  \
# 0  [{'institution': 'Lovely Professional Universi...
# 1  [{'institution': 'Local Engineering College', ...
# 2  [{'institution': 'Local Engineering College', ...
# ...

# %%
candidate = df.iloc[0]
parsed = parser.parse(candidate)
parsed  # for imp ranking feature extraction.
# Out:
# {'candidate_id': 'CAND_0000001',
#  'headline': 'Backend Engineer | SQL, Spark, Cloud',
#  'years_experience': 6.9,
#  'num_skills': 17,
#  'num_certifications': 0,
#  'profile_score': 86.9,
#  'open_to_work': 1}

# %%
df["profile"][0].keys()
# Out:
# dict_keys(['anonymized_name', 'headline', 'summary', 'location', 'country', 'years_of_experience', 'current_title', 'current_company', 'current_company_size', 'current_industry'])

# %%
df["redrob_signals"][0].keys()
# Out:
# dict_keys(['profile_completeness_score', 'signup_date', 'last_active_date', 'open_to_work_flag', 'profile_views_received_30d', 'applications_submitted_30d', 'recruiter_response_rate', 'avg_response_time_hours', 'skill_assessment_scores', 'connection_count', 'endorsements_received', 'notice_period_days', 'expected_salary_range_inr_lpa', 'preferred_work_mode', 'willing_to_relocate', 'github_activity_score', 'search_appearance_30d', 'saved_by_recruiters_30d', 'interview_completion_rate', 'offer_acceptance_rate', 'verified_email', 'verified_phone', 'linkedin_connected'])

# %%
from src.parser import CandidateParser

parser = CandidateParser()

parsed = parser.parse(df.iloc[0])

for k, v in parsed.items():
    print(f"{k}: {v}")
# Out:
# candidate_id: CAND_0000001
# headline: Backend Engineer | SQL, Spark, Cloud
# years_experience: 6.9
# num_skills: 17
# num_certifications: 0
# profile_score: 86.9
# open_to_work: 1

# %%
records = []

for _, row in df.head(1000).iterrows():
    records.append(
        parser.parse(row)
    )

parsed_df = pd.DataFrame(records)

print(parsed_df.shape)

parsed_df.head()
# Out:
# (1000, 7)
#    candidate_id                                       headline  \
# 0  CAND_0000001           Backend Engineer | SQL, Spark, Cloud
# 1  CAND_0000002      Operations Manager | 12.5+ yrs experience
# 2  CAND_0000003         Customer Support | 1.1+ yrs experience
# 3  CAND_0000004  Marketing Manager | Driving business outcomes
# 4  CAND_0000005               Accountant | Helping teams scale
#
#    years_experience  num_skills  num_certifications  profile_score  \
# 0               6.9          17                   0           86.9
# 1              12.5           9                   0           78.7
# 2               1.1           6                   0           31.9
# 3               3.8          10                   2           28.5
# 4              11.0           6                   0           84.6
#
#    open_to_work
# 0             1
# 1             1
# 2             0
# 3             0
# 4             1
